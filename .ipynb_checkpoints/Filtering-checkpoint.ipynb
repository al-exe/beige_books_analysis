# %% [markdown]
# ## Filtering

# %%
import pandas as pd

# %%
#download en on spaCy
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a685a33dad1e> in <module>()
#       1 #download en on spaCy
# ----> 2 import en_core_web_sm
#       3 nlp = en_core_web_sm.load()
#
# ModuleNotFoundError: No module named 'en_core_web_sm'

# %%
beige=pd.read_csv('noSS_table.csv')
beige.head()
# Out:
#    Unnamed: 0  ID       Date   District                Sector Heading  \
# 0           0   1  5-20-1970    Atlanta  Summary of Economic Activity
# 1           1   2  5-20-1970     Boston  Summary of Economic Activity
# 2           2   3  5-20-1970    Chicago  Summary of Economic Activity
# 3           3   4  5-20-1970  Cleveland  Summary of Economic Activity
# 4           4   5  5-20-1970     Dallas  Summary of Economic Activity
#
#                                          nostop_stem
# 0  ['mood', 'director', 'vary', 'pessimism', 'opt...
# 1  ['discussion', 'monday', '18', 'friday', 'dist...
# 2  ['publish', 'statement', 'private', 'conversat...
# 3  ['economic', 'activity', 'district', 'disrupt'...
# 4  ['continue', 'inflation', 'major', 'concern', ...

# %%
#converts the list of words back into list form (is read in as strings after converting to csv for some reason)
corpus = [eval(beige['nostop_stem'][i]) for i in range(len(beige))]
#type should be list
type(corpus[:3][0])
# Out:
# list

# %%
#makes table with a word column and part of speech column
def tablefier(parsed_text):
    toks_tab = pd.DataFrame()
    toks_tab['Word'] = [word.text for word in parsed_text]
    toks_tab['POS'] = [word.pos_ for word in parsed_text]
    return toks_tab

# %%
#creating a list of words that appear only once in entire corpus
one = pd.read_csv('noSS_onelist.csv')
ones = one.groupby('string').count()
oncewords = list(ones[ones['Unnamed: 0'] ==1].index)

# %% [markdown]
# #### This is the code block that took forever to run... D:

# %%
#for every record: getting rid of words that appear only once in entire corpus, keeping only nouns, verbs and adjectives.
new_corp = []
for t in beige['nostop_stem']:
    new = [word for word in eval(t) if word not in oncewords]
    parsed = nlp(str(new))
    gram = tablefier(parsed)
    gram = gram[(gram['POS'] == 'NOUN')|(gram['POS']=='VERB')|(gram['POS']=='ADJ')]
    new_corp.append(list(gram['Word']))

# %%
#adding a 'clean' column
beige['clean'] = new_corp

# %%
#saving new table as csv
beige.to_csv(path_or_buf = 'improved.csv', sep = ',', encoding='utf-8')

# %%
pd.read_csv('improved.csv')
# Out:
#        Unnamed: 0  Unnamed: 0.1     ID       Date       District  \
# 0               0             0      1  5-20-1970        Atlanta
# 1               1             1      2  5-20-1970         Boston
# 2               2             2      3  5-20-1970        Chicago
# 3               3             3      4  5-20-1970      Cleveland
# 4               4             4      5  5-20-1970         Dallas
# 5               5             5      6  5-20-1970    Kansas City
# 6               6             6      7  5-20-1970    Minneapolis
# 7               7             7      8  5-20-1970       New York
# 8               8             8      9  5-20-1970   Philadelphia
# 9               9             9     10  5-20-1970       Richmond
# 10             10            10     11  5-20-1970       Richmond
# 11             11            11     12  5-20-1970       Richmond
# 12             12            12     13  5-20-1970       Richmond
# 13             13            13     14  5-20-1970       Richmond
# 14             14            14     15  5-20-1970       Richmond
# 15             15            15     16  5-20-1970       Richmond
# 16             16            16     17  5-20-1970       Richmond
# 17             17            17     18  5-20-1970       Richmond
# 18             18            18     19  5-20-1970  San Francisco
# 19             19            19     20  5-20-1970  San Francisco
# 20             20            20     22  5-20-1970  San Francisco
# 21             21            21     23  5-20-1970  San Francisco
# 22             22            22     24  5-20-1970  San Francisco
# 23             23            23     25  5-20-1970  San Francisco
# 24             24            24     26  5-20-1970  San Francisco
# 25             25            25     27  5-20-1970  San Francisco
# 26             26            26     28  5-20-1970  San Francisco
# 27             27            27     29  5-20-1970  San Francisco
# 28             28            28     32  5-20-1970  San Francisco
# 29             29            29     33  5-20-1970  San Francisco
# ...           ...           ...    ...        ...            ...
# 25092       25092         25092  25240  1-17-2018   Philadelphia
# 25093       25093         25093  25241  1-17-2018   Philadelphia
# 25094       25094         25094  25242  1-17-2018   Philadelphia
# 25095       25095         25095  25243  1-17-2018       Richmond
# 25096       25096         25096  25244  1-17-2018       Richmond
# 25097       25097         25097  25245  1-17-2018       Richmond
# 25098       25098         25098  25246  1-17-2018       Richmond
# 25099       25099         25099  25247  1-17-2018       Richmond
# 25100       25100         25100  25248  1-17-2018       Richmond
# 25101       25101         25101  25249  1-17-2018       Richmond
# 25102       25102         25102  25250  1-17-2018       Richmond
# 25103       25103         25103  25251  1-17-2018       Richmond
# 25104       25104         25104  25252  1-17-2018       Richmond
# 25105       25105         25105  25253  1-17-2018  San Francisco
# 25106       25106         25106  25254  1-17-2018  San Francisco
# 25107       25107         25107  25255  1-17-2018  San Francisco
# 25108       25108         25108  25256  1-17-2018  San Francisco
# 25109       25109         25109  25257  1-17-2018  San Francisco
# 25110       25110         25110  25258  1-17-2018  San Francisco
# 25111       25111         25111  25259  1-17-2018  San Francisco
# 25112       25112         25112  25260  1-17-2018  San Francisco
# 25113       25113         25113  25261  1-17-2018       St Louis
# 25114       25114         25114  25262  1-17-2018       St Louis
# 25115       25115         25115  25263  1-17-2018       St Louis
# 25116       25116         25116  25264  1-17-2018       St Louis
# 25117       25117         25117  25265  1-17-2018       St Louis
# 25118       25118         25118  25266  1-17-2018       St Louis
# 25119       25119         25119  25267  1-17-2018       St Louis
# 25120       25120         25120  25268  1-17-2018       St Louis
# 25121       25121         25121  25269  1-17-2018       St Louis
#
#                                     Sector Heading  \
# 0                     Summary of Economic Activity
# 1                     Summary of Economic Activity
# 2                     Summary of Economic Activity
# 3                     Summary of Economic Activity
# 4                     Summary of Economic Activity
# 5                     Summary of Economic Activity
# 6                     Summary of Economic Activity
# 7                     Summary of Economic Activity
# 8                     Summary of Economic Activity
# 9               Production, Sales, and Inventories
# 10                     Employment and Unemployment
# 11                                Wages and Prices
# 12                                    Construction
# 13                                     Loan Demand
# 14                                         Outlook
# 15                                Capital Spending
# 16                            Inventory Investment
# 17        General Conditions and Consumer Spending
# 18                                         General
# 19                        Random Notes by Industry
# 20                                      Employment
# 21                                         Strikes
# 22                                           Wages
# 23                                     Other Costs
# 24                                          Prices
# 25                                         Profits
# 26                               Market Psychology
# 27                                           Sales
# 28                  Plant and Equipment Investment
# 29                                          Credit
# ...                                            ...
# 25092                        Nonfinancial Services
# 25093                           Financial Services
# 25094                 Real Estate and Construction
# 25095                 Summary of Economic Activity
# 25096                         Employment and Wages
# 25097                                       Prices
# 25098                                Manufacturing
# 25099                     Ports and Transportation
# 25100                  Retail, Travel, and Tourism
# 25101                 Real Estate and Construction
# 25102                          Banking and Finance
# 25103                       Non-Financial Services
# 25104            Agriculture and Natural Resources
# 25105                 Summary of Economic Activity
# 25106                         Employment and Wages
# 25107                                       Prices
# 25108                    Retail Trade and Services
# 25109                                Manufacturing
# 25110  Agriculture and Resource-Related Industries
# 25111                 Real Estate and Construction
# 25112                       Financial Institutions
# 25113                 Summary of Economic Activity
# 25114                         Employment and Wages
# 25115                                       Prices
# 25116                            Consumer Spending
# 25117                                Manufacturing
# 25118                        Nonfinancial Services
# 25119                 Real Estate and Construction
# 25120                          Banking and Finance
# 25121            Agriculture and Natural Resources
#
#                                              nostop_stem  \
# 0      ['mood', 'director', 'vary', 'pessimism', 'opt...
# 1      ['discussion', 'monday', '18', 'friday', 'dist...
# 2      ['publish', 'statement', 'private', 'conversat...
# 3      ['economic', 'activity', 'district', 'disrupt'...
# 4      ['continue', 'inflation', 'major', 'concern', ...
# 5      ['consensus', 'base', 'discussion', 'member', ...
# 6      ['indication', 'soften', 'ninth', 'federal', '...
# 7      ['second', 'federal', 'reserve', 'district', '...
# 8      ['business', 'slowdown', 'regional', 'economy'...
# 9      ['district', 'survey', 'respondent', 'certain'...
# 10     ['employment', 'report', 'decline', 'district'...
# 11     ['district', 'manufacturer', 'report', 'increa...
# 12     ['residential', 'construction', 'activity', 'd...
# 13     ['district', 'banker', 'report', 'demand', 'mo...
# 14     ['uncertainty', 'pervade', 'economic', 'outloo...
# 15     ['survey', 'respondent', 'manufacture', 'parti...
# 16     ['manufacturer', 'report', 'current', 'invento...
# 17     ['consensus', 'district', 'banker', 'decline',...
# 18     ['consistent', 'pattern', 'view', 'anticipatio...
# 19     ['report', 'recent', 'agricultural', 'conditio...
# 20     ['new', 'job', 'easy', 'find', 'actual', 'cutb...
# 21     ['current', 'anticipate', 'labor', 'difficulty...
# 22     ['wage', 'condition', 'vary', 'constant', 'ris...
# 23     ['increase', 'cost', 'purchase', 'good', 'ment...
# 24     ['price', 'respondent', 'product', 'vary', 're...
# 25     ['industry', 'expect', 'wage', 'increase', 'em...
# 26     ['sensitivecommodity', 'industry', 'psychology...
# 27     ['sale', 'report', 'vary', 'curtail', 'constan...
# 28     ['high', 'low', 'level', 'capital', 'spending'...
# 29     ['accord', 'banker', 'respondent', 'ample', 'a...
# ...                                                  ...
# 25092  ['balance', 'servicesector', 'firm', 'continue...
# 25093  ['financial', 'firm', 'report', 'modest', 'gro...
# 25094  ['homebuilder', 'continue', 'report', 'slight'...
# 25095  ['previous', 'report', 'fifth', 'district', 'e...
# 25096  ['balance', 'demand', 'labor', 'increase', 'mo...
# 25097  ['price', 'grow', 'modest', 'pace', 'overall',...
# 25098  ['district', 'manufacturing', 'activity', 'inc...
# 25099  ['district', 'port', 'report', 'robust', 'year...
# 25100  ['district', 'retailer', 'generally', 'report'...
# 25101  ['residential', 'real', 'estate', 'market', 'i...
# 25102  ['loan', 'demand', 'grow', 'modestly', 'recent...
# 25103  ['nonfinancial', 'service', 'firm', 'continue'...
# 25104  ['coal', 'production', 'little', 'changed', 'r...
# 25105  ['economic', 'activity', 'twelfth', 'district'...
# 25106  ['condition', 'labor', 'market', 'continue', '...
# 25107  ['overall', 'price', 'inflation', 'tick', 'sli...
# 25108  ['growth', 'retail', 'sale', 'pick', 'noticeab...
# 25109  ['condition', 'manufacturing', 'sector', 'rema...
# 25110  ['balance', 'activity', 'agriculture', 'sector...
# 25111  ['activity', 'real', 'estate', 'market', 'cont...
# 25112  ['lending', 'activity', 'firm', 'somewhat', 'r...
# 25113  ['report', 'contact', 'indicate', 'economic', ...
# 25114  ['anecdotal', 'evidence', 'suggest', 'little',...
# 25115  ['price', 'pressure', 'increase', 'moderately'...
# 25116  ['report', 'general', 'retailer', 'auto', 'dea...
# 25117  ['manufacturing', 'activity', 'increase', 'mod...
# 25118  ['activity', 'service', 'sector', 'expand', 'm...
# 25119  ['residential', 'real', 'estate', 'activity', ...
# 25120  ['banking', 'condition', 'eighth', 'district',...
# 25121  ['district', 'agriculture', 'condition', 'decl...
#
#                                                    clean
# 0      ['mood', 'director', 'vary', 'pessimism', 'opt...
# 1      ['discussion', 'monday', 'friday', 'district',...
# 2      ['publish', 'statement', 'private', 'conversat...
# 3      ['economic', 'activity', 'district', 'disrupt'...
# 4      ['continue', 'inflation', 'major', 'concern', ...
# 5      ['consensus', 'base', 'discussion', 'member', ...
# 6      ['indication', 'soften', 'ninth', 'federal', '...
# 7      ['second', 'federal', 'reserve', 'district', '...
# 8      ['business', 'slowdown', 'regional', 'economy'...
# 9      ['district', 'survey', 'respondent', 'certain'...
# 10     ['employment', 'report', 'decline', 'district'...
# 11     ['district', 'manufacturer', 'report', 'increa...
# 12     ['residential', 'construction', 'activity', 'd...
# 13     ['district', 'banker', 'report', 'demand', 'mo...
# 14     ['uncertainty', 'pervade', 'economic', 'outloo...
# 15     ['survey', 'respondent', 'manufacture', 'nondu...
# 16     ['manufacturer', 'report', 'current', 'invento...
# 17     ['consensus', 'district', 'banker', 'decline',...
# 18     ['consistent', 'pattern', 'view', 'anticipatio...
# 19     ['report', 'recent', 'agricultural', 'conditio...
# 20     ['new', 'job', 'easy', 'find', 'actual', 'cutb...
# 21     ['current', 'anticipate', 'labor', 'difficulty...
# 22     ['wage', 'condition', 'vary', 'constant', 'ris...
# 23     ['increase', 'cost', 'purchase', 'good', 'ment...
# 24     ['price', 'respondent', 'product', 'vary', 'st...
# 25     ['industry', 'expect', 'wage', 'increase', 'em...
# 26     ['industry', 'psychology', 'buyer', 'seller', ...
# 27     ['sale', 'report', 'vary', 'curtail', 'constan...
# 28     ['high', 'low', 'level', 'capital', 'spending'...
# 29     ['accord', 'banker', 'respondent', 'ample', 'a...
# ...                                                  ...
# 25092  ['balance', 'servicesector', 'firm', 'continue...
# 25093  ['financial', 'firm', 'report', 'modest', 'gro...
# 25094  ['homebuilder', 'continue', 'report', 'slight'...
# 25095  ['previous', 'report', 'fifth', 'district', 'e...
# 25096  ['balance', 'demand', 'labor', 'increase', 're...
# 25097  ['price', 'grow', 'modest', 'pace', 'previous'...
# 25098  ['district', 'manufacturing', 'activity', 'inc...
# 25099  ['district', 'port', 'report', 'robust', 'year...
# 25100  ['district', 'retailer', 'report', 'moderate',...
# 25101  ['residential', 'real', 'estate', 'market', 'i...
# 25102  ['loan', 'demand', 'grow', 'recent', 'week', '...
# 25103  ['nonfinancial', 'service', 'firm', 'continue'...
# 25104  ['coal', 'production', 'little', 'changed', 'r...
# 25105  ['economic', 'activity', 'twelfth', 'district'...
# 25106  ['condition', 'labor', 'market', 'continue', '...
# 25107  ['price', 'inflation', 'tick', 'reporting', 'p...
# 25108  ['growth', 'retail', 'sale', 'pick', 'reportin...
# 25109  ['condition', 'manufacturing', 'sector', 'rema...
# 25110  ['balance', 'activity', 'agriculture', 'sector...
# 25111  ['activity', 'real', 'estate', 'market', 'cont...
# 25112  ['lending', 'activity', 'firm', 'reporting', '...
# 25113  ['report', 'contact', 'indicate', 'economic', ...
# 25114  ['anecdotal', 'evidence', 'suggest', 'little',...
# 25115  ['price', 'pressure', 'increase', 'previous', ...
# 25116  ['report', 'general', 'retailer', 'auto', 'dea...
# 25117  ['manufacturing', 'activity', 'increase', 'pre...
# 25118  ['activity', 'service', 'sector', 'expand', 'p...
# 25119  ['residential', 'real', 'estate', 'activity', ...
# 25120  ['banking', 'condition', 'eighth', 'district',...
# 25121  ['district', 'agriculture', 'condition', 'decl...
#
# [25122 rows x 8 columns]
